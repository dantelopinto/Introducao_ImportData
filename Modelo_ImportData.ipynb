# %% [markdown]
# # <font color='grey'>**Portifólio de Cientista de Dados**<font>

# %% [markdown]
# ![Logo_560.png](data:image/png;base64,...)

# %% [markdown]
# # <font color='grey'>**Importação e Manipulação de diversos formatos de Dados em Python**</font>

# %% [markdown]
# ## <font color='grey'>1. Manipulando arquivos ZIP</font>

# %%
from zipfile import ZipFile
file = '/content/Logos.zip'
with ZipFile(file, 'r') as zip:
  zip.printdir()
  print('Extracting all the files now...')
  zip.extractall()
  print('Done!')
# Out:
# File Name                                             Modified             Size
# Logo_560.png                                   2025-02-06 15:52:56       458812
# Glass_Logo_560.png                             2025-02-10 16:21:48       472409
# Extracting all the files now...
# Done!

# %% [markdown]
# ## <font color='grey'>2. Lendo arquivos de imagens no Armazenamento Local</font>

# %%
from PIL import Image
# %matplotlib inline
img = Image.open("/content/Glass_Logo_560.png")
img.show()
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=560x560>

# %% [markdown]
# ## <font color='grey'>3. Lendo Arquivos de Video indexados da WEB</font>

# %%
HTML('''<<iframe width="560" height="315" src="https://www.youtube.com/embed/QrR_gm6RqCo?si=booNwDE_KmKi2zF-" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>''')
# Out:
# <<iframe width="560" height="315" src="https://www.youtube.com/embed/QrR_gm6RqCo?si=booNwDE_KmKi2zF-" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## <font color='grey'>4. Manipulando arquivos separados por vírgula CSV</font>

# %%
import pandas as pd
df = pd.read_csv('/content/Inscritos_P__s_LS.csv')
df
# Out:
#                                 email
# 0    tadeuconsultorsistemas@gmail.com
# 1                 ednammv@hotmail.com
# 2               joaogui21@hotmail.com
# 3            hudsonsouzask8@gmail.com
# 4           antoniomarcop@hotmail.com
# ..                                ...
# 251              alex.nasc@uol.com.br
# 252        viniciusdereck39@gmail.com
# 253             matheus1782@gmail.com
# 254    larissa.dias.souza@hotmail.com
# 255       analuazevedogomes@gmail.com
#
# [256 rows x 1 columns]

# %% [markdown]
# ## <font color='grey'>5. Manipulando arquivos .txt</font>

# %%
with open(r'/content/arquivo_texto.txt', 'r') as arquivo:
  print(arquivo.read())
# Out:
# Meu nome é Dante L. O. Pinto, sou um cientista de Dados!

# %%
with open(r'/content/arquivo_texto.txt', 'r') as arquivo:
  print(arquivo.readlines())
# Out:
# ['Meu nome é Dante L. O. Pinto, sou um cientista de Dados!']

# %% [markdown]
# ## <font color='grey'>6. Manipulando arquivos de excel</font>

# %%
df = pd.read_excel('/content/Wingspan.xlsx')
df
# Out:
#      Unnamed: 0  Unnamed: 1          Unnamed: 2               Unnamed: 3  \
# 0           NaN         NaN                Nome          NOME CIENTIFICO
# 1           NaN         NaN   CALIFORNIA CONDOR  Gymnogyps Californianus
# 2           NaN         NaN       BLACK VULTURE         Coragyps Atratus
# 3           NaN         NaN      TURKEY VULTURE           Cathartes Aura
# 4           NaN         NaN       CEDAR WAXWING     Vbombycilla Cedrorum
# ..          ...         ...                 ...                      ...
# 166         NaN         NaN      SANDHILL CRANE      Antigone Canadensis
# 167         NaN         NaN       STELLER'S JAY      Cyanocitta Stelleri
# 168         NaN         NaN  CLARK'S NUTCRACKER     Nucifraga Columbiana
# 169         NaN         NaN   NORTHERN BOBWHITE      Colinus Virginiarus
# 170         NaN         NaN    ACORN WOODPECKER  Melanerpes Formicivorus
#
#                         Unnamed: 4                      Unnamed: 5 Unnamed: 6  \
# ...

# %% [markdown]
# ## <font color='grey'>6.1. Lendo os nomes das planilhas</font>

# %%
xl = pd.ExcelFile('/content/Wingspan.xlsx')
xl.sheet_names
# Out:
# ['Aves', 'Objetivos de Final de Rodada', 'Objetivos Individuais', 'Categorias']

# %% [markdown]
# ## <font color='grey'>6.2. Abrindo planilhas específicas</font>

# %%
df = pd.read_excel('/content/Wingspan.xlsx', sheet_name = 'Categorias')
df
# Out:
#         Action      Localidades Comida Típica dos habitantes  \
# 0     Get Food             Pets          Seeds & Fruit & Rat
# 1     Get Food             Farm           Seeds & Worm & Rat
# 2     Get Food           Jungle           Fruit & Worm & Rat
# 3     Get Food           Forest          Fruit & Seeds & Rat
# 4     Get Baby            River            Worm & Fish & Rat
# 5     Get Baby           Safari           Worm & Fruit & Rat
# 6     Get Baby           Desert           Worm & Seeds & Rat
# 7   Get Animal              Sea           Fish & Seeds & Rat
# 8   Get Animal           Island           Fish & Fruit & Rat
# 9   Get Animal           Arctic            Fish & Worm & Rat
# 10         NaN              NaN                          NaN
# 11         NaN  Food (Wingspan)   Land (Magic The Gathering)
# 12         NaN            Seeds                       Plains
# 13         NaN            Fruit                       Forest
# ...

# %% [markdown]
# ## <font color='grey'>7. Manipulando arquivo em banco de dados SQLite</font>

# %%
import pandas as pd
import sqlite3
con = sqlite3.connect('/content/cdd.db')
cur = con.cursor()
Query = cur.execute('select * from produtos')
df = pd.DataFrame(Query.fetchall(), columns=['ID','DT','PRD','VL'])
con.commit()
df
# Out:
#     ID                          DT      PRD    VL
# 0   10         2018-05-02 14:32:11  Teclado  90.0
# 1   11  2018-04-18 16:01:53.996258  Monitor  74.0
# 2   12  2018-04-18 16:01:54.999582  Monitor  56.0
# 3   13  2018-04-18 16:01:56.010718  Monitor  78.0
# 4   14  2018-04-18 16:01:57.021711  Monitor  90.0
# 5   15  2018-04-18 16:01:58.033052  Monitor  82.0
# 6   16  2018-04-18 16:01:59.049664  Monitor  95.0
# 7   17  2018-04-18 16:02:00.059787  Monitor  57.0
# 8   18  2018-04-18 16:02:01.071106  Monitor  66.0
# 9   19  2018-04-18 16:02:02.082037  Monitor  94.0
# 10  20  2018-04-18 16:02:03.093071  Monitor  51.0

# %% [markdown]
# ## <font color='grey'>8. Manipulando arquivos JSON</font>

# %%
import json
with open('/content/JSON', 'r') as file:
  data = json.load(file)
print(type(data))
df_json = pd.DataFrame(data)
df_json
# Out:
# <class 'list'>
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#     idResumo ModalidadeDsc  NumeroEdital                    Data  DataAdiada  \
# 0        583  Concorrência   01/ANA/2018  12/02/2019 às 09:30:00        None
# 1        552        Pregão  001/ANA/2018  09/02/2018 às 09:00:00        None
# 2        553        Pregão  002/ANA/2018  09/02/2018 às 09:30:00        None
# 3        554        Pregão  003/ANA/2018  21/02/2018 às 08:30:00        None
# 4        555        Pregão  004/ANA/2018  21/02/2018 às 08:45:00        None
# 5        556        Pregão  005/ANA/2018  21/02/2018 às 09:00:00        None
# 6        557        Pregão  006/ANA/2018  21/02/2018 às 09:15:00        None
# ...
